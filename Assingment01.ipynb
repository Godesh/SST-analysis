# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import xarray as xr
import cartopy.crs as ccrs

# %%
a=[2,3,4] 
np.min(a)
# Out:
# 2

# %%
ds = xr.open_dataset('/home/pdirmeye/classes/clim680_2022/OISSTv2/monthly/sst.mnmean.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 180, lon: 360, time: 461, nbnds: 2)
# Coordinates:
#   * lat        (lat) float32 89.5 88.5 87.5 86.5 ... -86.5 -87.5 -88.5 -89.5
#   * lon        (lon) float32 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
#   * time       (time) datetime64[ns] 1981-12-01 1982-01-01 ... 2020-04-01
# Dimensions without coordinates: nbnds
# Data variables:
#     sst        (time, lat, lon) float32 ...
#     time_bnds  (time, nbnds) datetime64[ns] ...
# Attributes:
#     title:          NOAA Optimum Interpolation (OI) SST V2
#     Conventions:    CF-1.0
#     history:        Wed Apr  6 13:47:45 2005: ncks -d time,0,278 SAVEs/sst.mn...
#     comments:       Data described in  Reynolds, R.W., N.A. Rayner, T.M.\nSmi...
#     platform:       Model
#     source:         NCEP Climate Modeling Branch
#     institution:    National Centers for Environmental Prediction
#     References:     https://www.psl.noaa.gov/data/gridded/data.noaa.oisst.v2....
# ...

# %%
ds.sst[0, :, :].plot()

# %%
 = ax.pcolormesh(da_ocean.lon,da_ocean.lat,da_ocean,cmap='coolwarm',
                 transform = ccrs.PlateCarree())

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
cs = plt.contourf(ds.lon, ds.lat, ds.sst[0,:,:])
ax.coastlines()

# %%
a = 7
print(a)
# Out:
# 7

# %%
plt.contourf(ds_mean['tas'])
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/clim_data/lib/python3.10/site-packages/xarray/core/dataset.py:1395, in Dataset._construct_dataarray(self, name)
#    1394 try:
# -> 1395     variable = self._variables[name]
#    1396 except KeyError:
#
# KeyError: 'tas'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 plt.contourf(ds_mean['tas'])
#       2 plt.colorbar()
#
# File ~/.conda/envs/clim_data/lib/python3.10/site-packages/xarray/core/dataset.py:1499, in Dataset.__getitem__(self, key)
#    1496     return self.isel(**cast(Mapping, key))
#    1498 if hashable(key):
# -> 1499     return self._construct_dataarray(key)
#    1500 else:
#    1501     return self._copy_listed(key)
#
# ...

# %%
ds_mean=ds.mean(dim='time')

# %%
fig = plt.figure(figsize=(11,8.5))

# %%
ds_mean = ds.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 ds_mean = ds.mean()
#
# NameError: name 'ds' is not defined

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
cs = plt.contourf(ds.lon, ds.lat, ds.sst[0,:,:])
ax.coastlines()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 ax = plt.axes(projection=ccrs.PlateCarree())
#       2 cs = plt.contourf(ds.lon, ds.lat, ds.sst[0,:,:])
#       3 ax.coastlines()
#
# NameError: name 'plt' is not defined
